# %%
# %load_ext autoreload
# %autoreload
import argparse
import copy
import json
import os
import sys

sys.path.append("../")
sys.path.append("../src")

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import pandas as pd
from IPython import embed
from matplotlib import pyplot as plt
from torch.autograd import Variable


# %matplotlib inline

# %%
# %autoreload
import experiment
import experiment.resnet3d_binary as binary_experiment
import experiment.resnet3d_top20 as experiment
import src
from src.i3dense import I3DenseNet
from src.i3res import I3ResNet
from src.mit_data import MITDataset
from src.run import Run
from src.train import train, validation_loss

# %% [markdown]
# dataset = experiment.dataset
# dataloader = experiment.dataloader
# val_dataloader = experiment.val_dataloader
# resnet = torchvision.models.resnet50(pretrained=True)

# %%
run_binary = Run("../experiment/resnet3d_binary/low_lr_1218")
# Out:
# ../experiment/resnet3d_binary/low_lr_1218 is created
# ../experiment/resnet3d_binary/low_lr_1218/weights is created

# %%
cuda = torch.device("cuda:1")
dataloader = binary_experiment.dataloader
val_loader = binary_experiment.val_dataloader
model = binary_experiment.model
model.to(device=cuda)
# Out:
# I3ResNet(
#   (conv1): Conv3d(3, 64, kernel_size=(3, 7, 7), stride=(1, 2, 2), padding=(1, 3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool3d(kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), dilation=(1, 1, 1), ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck3d(
#       (conv1): Conv3d(64, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
# ...

# %%
# os.remove(run_binary.log_file)
train(
    dataloader,
    val_loader,
    model,
    init_lr=0.01,
    save_model_dir=run_binary.weights_dir,
    log_file=run_binary.log_file,
    device=cuda)
# Out:
# Step 0/64000.0
# ----------
# computing validation loss...
# validation error step:    1 loss: 0.6861
# step:   10 loss: 1.5094
# step:   20 loss: 2.6820
# step:   30 loss: 0.7805
# step:   40 loss: 0.8725
# step:   50 loss: 0.6838
# step:   60 loss: 0.8223
# step:   70 loss: 0.8026
# step:   80 loss: 0.7402
# step:   90 loss: 0.7336
# Step 91/64000.0
# ----------
# step:  100 loss: 0.7198
# ../experiment/resnet3d_binary/low_lr_1218/weights/000100.pt
# computing validation loss...
# validation error step:  101 loss: 0.8917
# step:  110 loss: 0.7256
# step:  120 loss: 0.7046
# step:  130 loss: 0.7309
# step:  140 loss: 0.7894
# step:  150 loss: 0.8075
# step:  160 loss: 0.7284
# step:  170 loss: 0.7562
# step:  180 loss: 0.6982
# Step 182/64000.0
# ----------
# step:  190 loss: 0.6726
# step:  200 loss: 0.8103
# ../experiment/resnet3d_binary/low_lr_1218/weights/000200.pt
# computing validation loss...
# validation error step:  201 loss: 0.6838
# step:  210 loss: 0.7502
# ...
